# %%
import clocked

for remaining in clocked.countdown_timer(5):
    blurry = (remaining / 5) * (100 / 100)
    print(blurry)
    if remaining >= 0:
        print(remaining)
# Out:
# 1.0
# 5
# 0.8
# 4
# 0.6
# 3
# 0.4
# 2
# 0.2
# 1

# %%
import time

time.monotonic()
# Out:
# 5949.0972442
