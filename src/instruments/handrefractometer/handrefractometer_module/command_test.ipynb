# %%
import handrefractometer_actions

# %%
handrefractometer_actions.open_lid()
# Out:
# closedLid:False
# Lid is opened
# (False, False, False, True, 6.666666666666666, False, 82, 'Lid is opened')

# %%
handrefractometer_actions.close_lid()
# Out:
# closedLid:True
# Lid is closed
# (True, False, False, True, 6.666666666666666, False, 40, 'Lid is closed')

# %%
handrefractometer_actions.calibrate()
# Out:
# calibrated:True, wiped:False
# Instrument calibrated successfully!
# Value should be back to zero (0)
# (False,
#  True,
#  False,
#  True,
#  6.666666666666666,
#  False,
#  0,
#  'Instrument calibrated successfully!\nValue should be back to zero (0)')

# %%
handrefractometer_actions.wipe()
# Out:
# wiped:True
# Lens wiped!
# (False, True, True, True, 6.666666666666666, False, 0, 'Lens wiped!')

# %%
handrefractometer_actions.sample()
# Out:
# sampled:True, wiped:False, calibrated:False
# Water sampled!
# (False, False, False, True, 6.666666666666666, False, 40, 'Water sampled!')

# %%
handrefractometer_actions.peek()
# Out:
# Sample first!
# (True, False, False, True, 6.666666666666666, True, 40, 'Sample first!')

# %%
import handrefractometer_actions

handrefractometer_actions.point_to_lightsource(remaining, 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import handrefractometer_actions
# ----> 3 handrefractometer_actions.point_to_lightsource(remaining, 15)
#
# NameError: name 'remaining' is not defined
